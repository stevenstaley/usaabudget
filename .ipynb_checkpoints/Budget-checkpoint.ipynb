# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# %%
DBUSER = os.getenv("DBUSER")
DBPSWD = os.getenv("DBPSWD")
DBIP = os.getenv("DBIP")
#comment
print(DBPSWD, DBUSER, DBIP)
# Out:
# None None None

# %%
DB_PORT = "3306"
DB_NAME = "budget"

engine = create_engine(
    f"mysql+pymysql://{DBUSER}:{DBPSWD}@{DBIP}:{DB_PORT}/{DB_NAME}"
)

def post_to_sql(df, table):
    df.to_sql(
    table,
    engine,
    if_exists="replace",
    index=False
)

# %%
main = pd.read_csv('main.csv')
main['Account'] = "Main"

# %%
bills = pd.read_csv('bills.csv')
bills['Account'] = "Bills"

# %%
savings = pd.read_csv('savings.csv')
savings['Account'] = "Main Savings"

# %%
full = pd.concat([bills, main, savings])

# %%
full['Date'] = pd.to_datetime(full['Date'])

# %%
df_clean = full[full["Category"] != "Transfer"].copy()

# %%
df_clean["month"] = df_clean["Date"].dt.to_period("M")

# %%
monthly = (
    df_clean
    .groupby("month")
    .agg(
        income=("Amount", lambda x: x[x > 0].sum()),
        expenses=("Amount", lambda x: abs(x[x < 0].sum()))
    )
    .reset_index()
)

monthly["month"] = monthly["month"].astype(str)

# %%
monthly['overunder'] = monthly['income'] - monthly['expenses']

# %%
# Only expenses
expenses_df = df_clean[df_clean["Amount"] < 0].copy()

# Sum expenses by Month and Category
monthly_category_df = (
    expenses_df
    .groupby(["month", "Category"], as_index=False)["Amount"]
    .sum()
)
monthly_category_df.sort_values(by="month", ascending=True, inplace=True)
print(monthly_category_df)
# Out:
#        month              Category  Amount
# 0    2025-06        Alcohol & Bars  -55.91
# 1    2025-06                Amazon -196.80
# 2    2025-06  Babysitter & Daycare -165.00
# 3    2025-06              Clothing -257.47
# 4    2025-06          Coffee Shops  -96.61
# ..       ...                   ...     ...
# 442  2026-06              Shopping  -30.80
# 443  2026-06                Target -138.31
# 444  2026-06            Television  -40.44
# 445  2026-06         Uncategorized -444.42
# 446  2026-06                 Water -137.58
#
# [447 rows x 3 columns]

# %%
patterns = ["Therapy Trails", "Childcare"]

regex = "|".join(patterns)

filtered_df = df_clean[~df_clean["Description"].str.contains(regex, regex=True, na=False)]
filtered_df
# Out:
#          Date                           Description  \
# 0  2026-06-17                         Georgia Power
# 1  2026-06-17                       Columbia County
# 2  2026-06-17                             Microsoft
# 3  2026-06-17                            discovery+
# 5  2026-06-16  USAA Property and Casualty Insurance
# ..        ...                                   ...
# 23 2025-10-31                         Interest Paid
# 25 2025-09-30                         Interest Paid
# 28 2025-08-29                         Interest Paid
# 29 2025-07-31                         Interest Paid
# 31 2025-06-30                         Interest Paid
#
#                            Original Description                Category  \
# 0   GPC              GPC EFT    ***********8EVN             Electricity
# 1      COLUMBIA COUNTY          706-863-6928 GA                   Water
# 2      Microsoft  Corporation   www.microsoftWA  Electronics & Software
# 3      discovery+               012-3456789  TN              Television
# 5   USAA P&C         AUTOPAY    ***********5738          Auto Insurance
# ..                                          ...                     ...
# 23                                INTEREST PAID         Interest Income
# 25                                INTEREST PAID         Interest Income
# 28                                INTEREST PAID         Interest Income
# 29                                INTEREST PAID         Interest Income
# 31                                INTEREST PAID         Interest Income
#
#     Amount  Status       Account    month
# 0  -300.48  Posted         Bills  2026-06
# 1  -137.58  Posted         Bills  2026-06
# 2   -23.70  Posted         Bills  2026-06
# 3    -6.56  Posted         Bills  2026-06
# 5  -145.42  Posted         Bills  2026-06
# ..     ...     ...           ...      ...
# 23    0.01  Posted  Main Savings  2025-10
# 25    0.01  Posted  Main Savings  2025-09
# 28    0.01  Posted  Main Savings  2025-08
# 29    0.01  Posted  Main Savings  2025-07
# 31    0.01  Posted  Main Savings  2025-06
#
# [1696 rows x 8 columns]

# %%
filtered_monthly = (
    filtered_df
    .groupby("month")
    .agg(
        income=("Amount", lambda x: x[x > 0].sum()),
        expenses=("Amount", lambda x: abs(x[x < 0].sum()))
    )
    .reset_index()
)

filtered_monthly["month"] = filtered_monthly["month"].astype(str)

# %%
filtered_monthly
# Out:
#       month    income  expenses
# 0   2025-06   3892.63   3824.40
# 1   2025-07   7628.90  13238.25
# 2   2025-08   7740.31   9735.16
# 3   2025-09   7628.91   8396.98
# 4   2025-10   7657.92   9641.93
# 5   2025-11   7732.38  13198.28
# 6   2025-12   9518.27  12003.77
# 7   2026-01   8107.89   9490.15
# 8   2026-02  14502.29  11753.56
# 9   2026-03   8045.88  15450.82
# 10  2026-04   8105.88   9444.76
# 11  2026-05   8544.38   8502.43
# 12  2026-06   4004.36   8306.34

# %%
filtered_monthly['overunder'] = filtered_monthly['income'] - filtered_monthly['expenses']

# %%
total = monthly['income'].sum() - monthly['expenses'].sum()

# %%
filtered_total = filtered_monthly['income'].sum() - filtered_monthly['expenses'].sum()

# %%
post_to_sql(df_clean, "clean")

# %%
post_to_sql(full, "full")

# %%
post_to_sql(filtered_df, "filtered")

# %%
post_to_sql(filtered_monthly, "filtered_monthly")

# %%
post_to_sql(monthly, "monthly")

# %%
post_to_sql(monthly_category_df, "mo_by_ategory")

# %%
'steven-staley'@'steven-HP-EliteBook-840-G5.tailfd5cf2.ts.net'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 'steven-staley'@'steven-HP-EliteBook-840-G5.tailfd5cf2.ts.net'
#
# TypeError: unsupported operand type(s) for @: 'str' and 'str'
